# %%
import torch
from network import NormConstrainedResNet

DEVICE = "cpu"

model1 = NormConstrainedResNet(num_classes=10).to(DEVICE)
model1.load_state_dict(torch.load("models/model_no_norm_W2.pt", map_location=DEVICE)['model_state_dict'])
model1.state_dict()
# Out:
# OrderedDict([('W',
#               tensor([[0.7957, 0.6648, 0.0036,  ..., 0.2186, 0.6988, 0.0245],
#                       [0.9149, 0.9929, 0.8293,  ..., 0.8201, 0.9952, 0.6460],
#                       [0.2655, 0.2397, 0.7332,  ..., 0.0469, 0.9870, 0.5699],
#                       ...,
#                       [0.4206, 0.0212, 0.0988,  ..., 0.4790, 0.3554, 0.9871],
#                       [0.7838, 0.5512, 0.3955,  ..., 0.2903, 0.3485, 0.8667],
#                       [0.2083, 0.5359, 0.5913,  ..., 0.1227, 0.1030, 0.9498]])),
#              ('resnet.conv1.weight',
#               tensor([[[[ 2.0510e-02, -1.1147e-02, -3.0730e-02,  ...,  8.8521e-03,
#                          -1.4474e-03, -2.0092e-02],
#                         [-3.8346e-02, -3.3085e-02, -1.5209e-02,  ...,  1.9134e-02,
#                          -2.1797e-02,  2.9667e-03],
#                         [ 2.8032e-02, -3.7900e-03, -5.8882e-02,  ..., -4.0016e-02,
#                          -1.3565e-02,  2.0259e-02],
# ...
